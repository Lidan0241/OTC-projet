# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr, spearmanr
import matplotlib as plt
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine
import gensim
from gensim.models import KeyedVectors

# %%
df = pd.read_csv('dataframe.csv')
title_length = df['title_word_count'].tolist()
content_length = df['content_word_count'].tolist()
theme_list = df['theme'].tolist()
frequent_word_list = df['frequent_word'].tolist()
print(title_length)
print(content_length)
print(theme_list)
print(frequent_word_list)
# Out:
# [20, 16, 12, 16, 14, 18, 14, 23, 20, 19, 19, 13, 11, 19, 12, 17, 16, 18, 20, 21, 21, 23, 18, 13]
# [462, 230, 468, 579, 312, 332, 448, 431, 523, 414, 164, 470, 356, 232, 404, 401, 353, 1278, 534, 393, 393, 206, 1062, 658]
# ['société', 'international', 'international', 'sport', 'politique', 'société', 'société', 'politique', 'afrique', 'economie', 'international', 'disparitions', 'afrique', 'afrique', 'afrique', 'politique', 'sante', 'politique', 'politique', 'elections-europeennes', 'elections-europeennes', 'international', 'international', 'société']
# ['étudiant', 'poulter', 'loi', 'match', 'conseiller', 'administratif', 'nom', 'université', 'burkinabé', 'ligne', 'université', 'celui', 'mine', 'neuf', 'américain', 'liste', 'cour', 'bardella', 'proportionnelle', 'vote', 'vote', 'ukraine', 'président', 'notte']

# %%
# coefficient de corrélation de Pearson
pearson_corr, pearson_pvalue = pearsonr(title_length, content_length)
print("Corrélation de Pearson:", pearson_corr, "P-value:", pearson_pvalue)

# coefficient de corrélation de Spearman
spearman_corr, spearman_pvalue = spearmanr(title_length, content_length)
print("Corrélation de Spearman:", spearman_corr, "P-value:", spearman_pvalue)

# il n'y donc pas de corrélation entre la longueur de résumé et la longueur de contenu des articles.
# Out:
# Corrélation de Pearson: -0.04704119272939889 P-value: 0.8272173534614076
# Corrélation de Spearman: -0.13368410666494643 P-value: 0.5334427271461915

# %%
# loading a pretrained model for word2vec
model = KeyedVectors.load_word2vec_format("./model_word2vec.bin", binary=True, unicode_errors="ignore")

# conversion vecteurs + calcul similarité cosine
for theme in theme_list:
    for word in frequent_word_list:
        if theme in model and word in model:
            similarity = model.similarity(theme, word)
            print(f"similarité entre {theme} et {word}: {similarity:.4f}")
        else:
            print(f"One of the words, {theme} or {word}, is not in the vocabulary.")
# Out:
# similarité entre société et étudiant: -0.0833
# One of the words, société or poulter, is not in the vocabulary.
# similarité entre société et loi: 0.1048
# similarité entre société et match: -0.1153
# similarité entre société et conseiller: -0.0243
# similarité entre société et administratif: -0.0082
# similarité entre société et nom: 0.0742
# similarité entre société et université: -0.0292
# similarité entre société et burkinabé: -0.0446
# similarité entre société et ligne: 0.0513
# similarité entre société et université: -0.0292
# similarité entre société et celui: 0.0148
# similarité entre société et mine: 0.0440
# similarité entre société et neuf: 0.0143
# similarité entre société et américain: 0.0651
# similarité entre société et liste: -0.0598
# similarité entre société et cour: 0.0581
# One of the words, société or bardella, is not in the vocabulary.
# similarité entre société et proportionnelle: -0.0631
# similarité entre société et vote: 0.0386
# similarité entre société et vote: 0.0386
# similarité entre société et ukraine: -0.0491
# similarité entre société et président: 0.0573
# similarité entre société et notte: -0.0732
# similarité entre international et étudiant: -0.0241
# One of the words, international or poulter, is not in the vocabulary.
# similarité entre international et loi: -0.0599
# similarité entre international et match: -0.0095
# similarité entre international et conseiller: -0.0140
# similarité entre international et administratif: 0.0383
# similarité entre international et nom: -0.0326
# similarité entre international et université: 0.2222
# similarité entre international et burkinabé: 0.1191
# similarité entre international et ligne: 0.0202
# similarité entre international et université: 0.2222
# similarité entre international et celui: -0.0130
# similarité entre international et mine: -0.0369
# similarité entre international et neuf: -0.0306
# similarité entre international et américain: 0.2705
# similarité entre international et liste: -0.0982
# similarité entre international et cour: 0.1264
# One of the words, international or bardella, is not in the vocabulary.
# similarité entre international et proportionnelle: -0.0762
# similarité entre international et vote: -0.0734
# similarité entre international et vote: -0.0734
# similarité entre international et ukraine: 0.1872
# similarité entre international et président: 0.0592
# similarité entre international et notte: 0.0129
# similarité entre international et étudiant: -0.0241
# One of the words, international or poulter, is not in the vocabulary.
# similarité entre international et loi: -0.0599
# similarité entre international et match: -0.0095
# similarité entre international et conseiller: -0.0140
# similarité entre international et administratif: 0.0383
# similarité entre international et nom: -0.0326
# similarité entre international et université: 0.2222
# similarité entre international et burkinabé: 0.1191
# similarité entre international et ligne: 0.0202
# similarité entre international et université: 0.2222
# similarité entre international et celui: -0.0130
# similarité entre international et mine: -0.0369
# similarité entre international et neuf: -0.0306
# similarité entre international et américain: 0.2705
# similarité entre international et liste: -0.0982
# similarité entre international et cour: 0.1264
# One of the words, international or bardella, is not in the vocabulary.
# similarité entre international et proportionnelle: -0.0762
# similarité entre international et vote: -0.0734
# similarité entre international et vote: -0.0734
# similarité entre international et ukraine: 0.1872
# similarité entre international et président: 0.0592
# similarité entre international et notte: 0.0129
# similarité entre sport et étudiant: 0.0043
# One of the words, sport or poulter, is not in the vocabulary.
# similarité entre sport et loi: -0.0239
# similarité entre sport et match: 0.1382
# similarité entre sport et conseiller: -0.0055
# similarité entre sport et administratif: 0.0279
# similarité entre sport et nom: -0.0628
# similarité entre sport et université: -0.0271
# similarité entre sport et burkinabé: -0.0478
# similarité entre sport et ligne: -0.0298
# similarité entre sport et université: -0.0271
# similarité entre sport et celui: -0.0328
# similarité entre sport et mine: -0.0782
# similarité entre sport et neuf: 0.0016
# similarité entre sport et américain: 0.0336
# similarité entre sport et liste: -0.0839
# similarité entre sport et cour: -0.0175
# One of the words, sport or bardella, is not in the vocabulary.
# similarité entre sport et proportionnelle: -0.0689
# similarité entre sport et vote: -0.0406
# similarité entre sport et vote: -0.0406
# similarité entre sport et ukraine: -0.0454
# similarité entre sport et président: 0.0304
# similarité entre sport et notte: -0.1072
# similarité entre politique et étudiant: -0.0868
# One of the words, politique or poulter, is not in the vocabulary.
# similarité entre politique et loi: 0.0643
# similarité entre politique et match: -0.0564
# similarité entre politique et conseiller: 0.0990
# similarité entre politique et administratif: -0.0001
# similarité entre politique et nom: -0.0611
# similarité entre politique et université: 0.0316
# similarité entre politique et burkinabé: 0.1143
# similarité entre politique et ligne: -0.0133
# similarité entre politique et université: 0.0316
# similarité entre politique et celui: 0.0297
# similarité entre politique et mine: 0.0213
# similarité entre politique et neuf: -0.0250
# similarité entre politique et américain: 0.0714
# similarité entre politique et liste: 0.0023
# similarité entre politique et cour: -0.0334
# One of the words, politique or bardella, is not in the vocabulary.
# similarité entre politique et proportionnelle: 0.0730
# similarité entre politique et vote: 0.1660
# similarité entre politique et vote: 0.1660
# similarité entre politique et ukraine: 0.0651
# similarité entre politique et président: 0.1754
# similarité entre politique et notte: -0.0801
# similarité entre société et étudiant: -0.0833
# One of the words, société or poulter, is not in the vocabulary.
# similarité entre société et loi: 0.1048
# similarité entre société et match: -0.1153
# similarité entre société et conseiller: -0.0243
# similarité entre société et administratif: -0.0082
# similarité entre société et nom: 0.0742
# similarité entre société et université: -0.0292
# similarité entre société et burkinabé: -0.0446
# similarité entre société et ligne: 0.0513
# similarité entre société et université: -0.0292
# similarité entre société et celui: 0.0148
# similarité entre société et mine: 0.0440
# similarité entre société et neuf: 0.0143
# similarité entre société et américain: 0.0651
# similarité entre société et liste: -0.0598
# similarité entre société et cour: 0.0581
# One of the words, société or bardella, is not in the vocabulary.
# similarité entre société et proportionnelle: -0.0631
# similarité entre société et vote: 0.0386
# similarité entre société et vote: 0.0386
# similarité entre société et ukraine: -0.0491
# similarité entre société et président: 0.0573
# similarité entre société et notte: -0.0732
# similarité entre société et étudiant: -0.0833
# One of the words, société or poulter, is not in the vocabulary.
# similarité entre société et loi: 0.1048
# similarité entre société et match: -0.1153
# similarité entre société et conseiller: -0.0243
# similarité entre société et administratif: -0.0082
# similarité entre société et nom: 0.0742
# similarité entre société et université: -0.0292
# similarité entre société et burkinabé: -0.0446
# similarité entre société et ligne: 0.0513
# similarité entre société et université: -0.0292
# similarité entre société et celui: 0.0148
# similarité entre société et mine: 0.0440
# similarité entre société et neuf: 0.0143
# similarité entre société et américain: 0.0651
# similarité entre société et liste: -0.0598
# similarité entre société et cour: 0.0581
# One of the words, société or bardella, is not in the vocabulary.
# similarité entre société et proportionnelle: -0.0631
# similarité entre société et vote: 0.0386
# similarité entre société et vote: 0.0386
# similarité entre société et ukraine: -0.0491
# similarité entre société et président: 0.0573
# similarité entre société et notte: -0.0732
# similarité entre politique et étudiant: -0.0868
# One of the words, politique or poulter, is not in the vocabulary.
# similarité entre politique et loi: 0.0643
# similarité entre politique et match: -0.0564
# similarité entre politique et conseiller: 0.0990
# similarité entre politique et administratif: -0.0001
# similarité entre politique et nom: -0.0611
# similarité entre politique et université: 0.0316
# similarité entre politique et burkinabé: 0.1143
# similarité entre politique et ligne: -0.0133
# similarité entre politique et université: 0.0316
# similarité entre politique et celui: 0.0297
# similarité entre politique et mine: 0.0213
# similarité entre politique et neuf: -0.0250
# similarité entre politique et américain: 0.0714
# similarité entre politique et liste: 0.0023
# similarité entre politique et cour: -0.0334
# One of the words, politique or bardella, is not in the vocabulary.
# similarité entre politique et proportionnelle: 0.0730
# similarité entre politique et vote: 0.1660
# similarité entre politique et vote: 0.1660
# similarité entre politique et ukraine: 0.0651
# similarité entre politique et président: 0.1754
# similarité entre politique et notte: -0.0801
# similarité entre afrique et étudiant: -0.0843
# One of the words, afrique or poulter, is not in the vocabulary.
# similarité entre afrique et loi: -0.0860
# similarité entre afrique et match: 0.0279
# similarité entre afrique et conseiller: -0.0518
# similarité entre afrique et administratif: -0.0459
# similarité entre afrique et nom: -0.0854
# similarité entre afrique et université: 0.0170
# similarité entre afrique et burkinabé: 0.4329
# similarité entre afrique et ligne: -0.0312
# similarité entre afrique et université: 0.0170
# similarité entre afrique et celui: -0.0226
# similarité entre afrique et mine: 0.1052
# similarité entre afrique et neuf: 0.0586
# similarité entre afrique et américain: 0.1519
# similarité entre afrique et liste: -0.0343
# similarité entre afrique et cour: 0.0000
# One of the words, afrique or bardella, is not in the vocabulary.
# similarité entre afrique et proportionnelle: -0.0863
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et ukraine: 0.1347
# similarité entre afrique et président: 0.0777
# similarité entre afrique et notte: -0.0164
# similarité entre economie et étudiant: 0.0275
# One of the words, economie or poulter, is not in the vocabulary.
# similarité entre economie et loi: 0.0912
# similarité entre economie et match: -0.0278
# similarité entre economie et conseiller: 0.0752
# similarité entre economie et administratif: 0.0688
# similarité entre economie et nom: -0.1022
# similarité entre economie et université: 0.2165
# similarité entre economie et burkinabé: 0.0572
# similarité entre economie et ligne: 0.0317
# similarité entre economie et université: 0.2165
# similarité entre economie et celui: -0.1954
# similarité entre economie et mine: 0.0145
# similarité entre economie et neuf: 0.0486
# similarité entre economie et américain: 0.0872
# similarité entre economie et liste: -0.0028
# similarité entre economie et cour: 0.0079
# One of the words, economie or bardella, is not in the vocabulary.
# similarité entre economie et proportionnelle: -0.1003
# similarité entre economie et vote: -0.0238
# similarité entre economie et vote: -0.0238
# similarité entre economie et ukraine: 0.0343
# similarité entre economie et président: 0.1025
# similarité entre economie et notte: -0.0576
# similarité entre international et étudiant: -0.0241
# One of the words, international or poulter, is not in the vocabulary.
# similarité entre international et loi: -0.0599
# similarité entre international et match: -0.0095
# similarité entre international et conseiller: -0.0140
# similarité entre international et administratif: 0.0383
# similarité entre international et nom: -0.0326
# similarité entre international et université: 0.2222
# similarité entre international et burkinabé: 0.1191
# similarité entre international et ligne: 0.0202
# similarité entre international et université: 0.2222
# similarité entre international et celui: -0.0130
# similarité entre international et mine: -0.0369
# similarité entre international et neuf: -0.0306
# similarité entre international et américain: 0.2705
# similarité entre international et liste: -0.0982
# similarité entre international et cour: 0.1264
# One of the words, international or bardella, is not in the vocabulary.
# similarité entre international et proportionnelle: -0.0762
# similarité entre international et vote: -0.0734
# similarité entre international et vote: -0.0734
# similarité entre international et ukraine: 0.1872
# similarité entre international et président: 0.0592
# similarité entre international et notte: 0.0129
# similarité entre disparitions et étudiant: -0.1083
# One of the words, disparitions or poulter, is not in the vocabulary.
# similarité entre disparitions et loi: -0.0709
# similarité entre disparitions et match: 0.0015
# similarité entre disparitions et conseiller: -0.0044
# similarité entre disparitions et administratif: 0.0918
# similarité entre disparitions et nom: 0.0205
# similarité entre disparitions et université: -0.1287
# similarité entre disparitions et burkinabé: 0.0583
# similarité entre disparitions et ligne: 0.0597
# similarité entre disparitions et université: -0.1287
# similarité entre disparitions et celui: -0.1048
# similarité entre disparitions et mine: 0.0480
# similarité entre disparitions et neuf: 0.0117
# similarité entre disparitions et américain: 0.0019
# similarité entre disparitions et liste: 0.0615
# similarité entre disparitions et cour: 0.0426
# One of the words, disparitions or bardella, is not in the vocabulary.
# similarité entre disparitions et proportionnelle: -0.0935
# similarité entre disparitions et vote: -0.0646
# similarité entre disparitions et vote: -0.0646
# similarité entre disparitions et ukraine: 0.0993
# similarité entre disparitions et président: -0.0406
# similarité entre disparitions et notte: 0.0180
# similarité entre afrique et étudiant: -0.0843
# One of the words, afrique or poulter, is not in the vocabulary.
# similarité entre afrique et loi: -0.0860
# similarité entre afrique et match: 0.0279
# similarité entre afrique et conseiller: -0.0518
# similarité entre afrique et administratif: -0.0459
# similarité entre afrique et nom: -0.0854
# similarité entre afrique et université: 0.0170
# similarité entre afrique et burkinabé: 0.4329
# similarité entre afrique et ligne: -0.0312
# similarité entre afrique et université: 0.0170
# similarité entre afrique et celui: -0.0226
# similarité entre afrique et mine: 0.1052
# similarité entre afrique et neuf: 0.0586
# similarité entre afrique et américain: 0.1519
# similarité entre afrique et liste: -0.0343
# similarité entre afrique et cour: 0.0000
# One of the words, afrique or bardella, is not in the vocabulary.
# similarité entre afrique et proportionnelle: -0.0863
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et ukraine: 0.1347
# similarité entre afrique et président: 0.0777
# similarité entre afrique et notte: -0.0164
# similarité entre afrique et étudiant: -0.0843
# One of the words, afrique or poulter, is not in the vocabulary.
# similarité entre afrique et loi: -0.0860
# similarité entre afrique et match: 0.0279
# similarité entre afrique et conseiller: -0.0518
# similarité entre afrique et administratif: -0.0459
# similarité entre afrique et nom: -0.0854
# similarité entre afrique et université: 0.0170
# similarité entre afrique et burkinabé: 0.4329
# similarité entre afrique et ligne: -0.0312
# similarité entre afrique et université: 0.0170
# similarité entre afrique et celui: -0.0226
# similarité entre afrique et mine: 0.1052
# similarité entre afrique et neuf: 0.0586
# similarité entre afrique et américain: 0.1519
# similarité entre afrique et liste: -0.0343
# similarité entre afrique et cour: 0.0000
# One of the words, afrique or bardella, is not in the vocabulary.
# similarité entre afrique et proportionnelle: -0.0863
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et ukraine: 0.1347
# similarité entre afrique et président: 0.0777
# similarité entre afrique et notte: -0.0164
# similarité entre afrique et étudiant: -0.0843
# One of the words, afrique or poulter, is not in the vocabulary.
# similarité entre afrique et loi: -0.0860
# similarité entre afrique et match: 0.0279
# similarité entre afrique et conseiller: -0.0518
# similarité entre afrique et administratif: -0.0459
# similarité entre afrique et nom: -0.0854
# similarité entre afrique et université: 0.0170
# similarité entre afrique et burkinabé: 0.4329
# similarité entre afrique et ligne: -0.0312
# similarité entre afrique et université: 0.0170
# similarité entre afrique et celui: -0.0226
# similarité entre afrique et mine: 0.1052
# similarité entre afrique et neuf: 0.0586
# similarité entre afrique et américain: 0.1519
# similarité entre afrique et liste: -0.0343
# similarité entre afrique et cour: 0.0000
# One of the words, afrique or bardella, is not in the vocabulary.
# similarité entre afrique et proportionnelle: -0.0863
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et vote: -0.0294
# similarité entre afrique et ukraine: 0.1347
# similarité entre afrique et président: 0.0777
# similarité entre afrique et notte: -0.0164
# similarité entre politique et étudiant: -0.0868
# One of the words, politique or poulter, is not in the vocabulary.
# similarité entre politique et loi: 0.0643
# similarité entre politique et match: -0.0564
# similarité entre politique et conseiller: 0.0990
# similarité entre politique et administratif: -0.0001
# similarité entre politique et nom: -0.0611
# similarité entre politique et université: 0.0316
# similarité entre politique et burkinabé: 0.1143
# similarité entre politique et ligne: -0.0133
# similarité entre politique et université: 0.0316
# similarité entre politique et celui: 0.0297
# similarité entre politique et mine: 0.0213
# similarité entre politique et neuf: -0.0250
# similarité entre politique et américain: 0.0714
# similarité entre politique et liste: 0.0023
# similarité entre politique et cour: -0.0334
# One of the words, politique or bardella, is not in the vocabulary.
# similarité entre politique et proportionnelle: 0.0730
# similarité entre politique et vote: 0.1660
# similarité entre politique et vote: 0.1660
# similarité entre politique et ukraine: 0.0651
# similarité entre politique et président: 0.1754
# similarité entre politique et notte: -0.0801
# similarité entre sante et étudiant: -0.0555
# One of the words, sante or poulter, is not in the vocabulary.
# similarité entre sante et loi: 0.0485
# similarité entre sante et match: -0.0665
# similarité entre sante et conseiller: 0.0703
# similarité entre sante et administratif: 0.0323
# similarité entre sante et nom: -0.0463
# similarité entre sante et université: 0.0388
# similarité entre sante et burkinabé: 0.0451
# similarité entre sante et ligne: 0.0404
# similarité entre sante et université: 0.0388
# similarité entre sante et celui: -0.0999
# similarité entre sante et mine: -0.0410
# similarité entre sante et neuf: -0.0254
# similarité entre sante et américain: -0.0777
# similarité entre sante et liste: 0.0431
# similarité entre sante et cour: -0.0127
# One of the words, sante or bardella, is not in the vocabulary.
# similarité entre sante et proportionnelle: 0.0070
# similarité entre sante et vote: 0.0376
# similarité entre sante et vote: 0.0376
# similarité entre sante et ukraine: 0.0220
# similarité entre sante et président: -0.0215
# similarité entre sante et notte: 0.0691
# similarité entre politique et étudiant: -0.0868
# One of the words, politique or poulter, is not in the vocabulary.
# similarité entre politique et loi: 0.0643
# similarité entre politique et match: -0.0564
# similarité entre politique et conseiller: 0.0990
# similarité entre politique et administratif: -0.0001
# similarité entre politique et nom: -0.0611
# similarité entre politique et université: 0.0316
# similarité entre politique et burkinabé: 0.1143
# similarité entre politique et ligne: -0.0133
# similarité entre politique et université: 0.0316
# similarité entre politique et celui: 0.0297
# similarité entre politique et mine: 0.0213
# similarité entre politique et neuf: -0.0250
# similarité entre politique et américain: 0.0714
# similarité entre politique et liste: 0.0023
# similarité entre politique et cour: -0.0334
# One of the words, politique or bardella, is not in the vocabulary.
# similarité entre politique et proportionnelle: 0.0730
# similarité entre politique et vote: 0.1660
# similarité entre politique et vote: 0.1660
# similarité entre politique et ukraine: 0.0651
# similarité entre politique et président: 0.1754
# similarité entre politique et notte: -0.0801
# similarité entre politique et étudiant: -0.0868
# One of the words, politique or poulter, is not in the vocabulary.
# similarité entre politique et loi: 0.0643
# similarité entre politique et match: -0.0564
# similarité entre politique et conseiller: 0.0990
# similarité entre politique et administratif: -0.0001
# similarité entre politique et nom: -0.0611
# similarité entre politique et université: 0.0316
# similarité entre politique et burkinabé: 0.1143
# similarité entre politique et ligne: -0.0133
# similarité entre politique et université: 0.0316
# similarité entre politique et celui: 0.0297
# similarité entre politique et mine: 0.0213
# similarité entre politique et neuf: -0.0250
# similarité entre politique et américain: 0.0714
# similarité entre politique et liste: 0.0023
# similarité entre politique et cour: -0.0334
# One of the words, politique or bardella, is not in the vocabulary.
# similarité entre politique et proportionnelle: 0.0730
# similarité entre politique et vote: 0.1660
# similarité entre politique et vote: 0.1660
# similarité entre politique et ukraine: 0.0651
# similarité entre politique et président: 0.1754
# similarité entre politique et notte: -0.0801
# One of the words, elections-europeennes or étudiant, is not in the vocabulary.
# One of the words, elections-europeennes or poulter, is not in the vocabulary.
# One of the words, elections-europeennes or loi, is not in the vocabulary.
# One of the words, elections-europeennes or match, is not in the vocabulary.
# One of the words, elections-europeennes or conseiller, is not in the vocabulary.
# One of the words, elections-europeennes or administratif, is not in the vocabulary.
# One of the words, elections-europeennes or nom, is not in the vocabulary.
# One of the words, elections-europeennes or université, is not in the vocabulary.
# One of the words, elections-europeennes or burkinabé, is not in the vocabulary.
# One of the words, elections-europeennes or ligne, is not in the vocabulary.
# One of the words, elections-europeennes or université, is not in the vocabulary.
# One of the words, elections-europeennes or celui, is not in the vocabulary.
# One of the words, elections-europeennes or mine, is not in the vocabulary.
# One of the words, elections-europeennes or neuf, is not in the vocabulary.
# One of the words, elections-europeennes or américain, is not in the vocabulary.
# One of the words, elections-europeennes or liste, is not in the vocabulary.
# One of the words, elections-europeennes or cour, is not in the vocabulary.
# One of the words, elections-europeennes or bardella, is not in the vocabulary.
# One of the words, elections-europeennes or proportionnelle, is not in the vocabulary.
# One of the words, elections-europeennes or vote, is not in the vocabulary.
# One of the words, elections-europeennes or vote, is not in the vocabulary.
# One of the words, elections-europeennes or ukraine, is not in the vocabulary.
# One of the words, elections-europeennes or président, is not in the vocabulary.
# One of the words, elections-europeennes or notte, is not in the vocabulary.
# One of the words, elections-europeennes or étudiant, is not in the vocabulary.
# One of the words, elections-europeennes or poulter, is not in the vocabulary.
# One of the words, elections-europeennes or loi, is not in the vocabulary.
# One of the words, elections-europeennes or match, is not in the vocabulary.
# One of the words, elections-europeennes or conseiller, is not in the vocabulary.
# One of the words, elections-europeennes or administratif, is not in the vocabulary.
# One of the words, elections-europeennes or nom, is not in the vocabulary.
# One of the words, elections-europeennes or université, is not in the vocabulary.
# One of the words, elections-europeennes or burkinabé, is not in the vocabulary.
# One of the words, elections-europeennes or ligne, is not in the vocabulary.
# One of the words, elections-europeennes or université, is not in the vocabulary.
# One of the words, elections-europeennes or celui, is not in the vocabulary.
# One of the words, elections-europeennes or mine, is not in the vocabulary.
# One of the words, elections-europeennes or neuf, is not in the vocabulary.
# One of the words, elections-europeennes or américain, is not in the vocabulary.
# One of the words, elections-europeennes or liste, is not in the vocabulary.
# One of the words, elections-europeennes or cour, is not in the vocabulary.
# One of the words, elections-europeennes or bardella, is not in the vocabulary.
# One of the words, elections-europeennes or proportionnelle, is not in the vocabulary.
# One of the words, elections-europeennes or vote, is not in the vocabulary.
# One of the words, elections-europeennes or vote, is not in the vocabulary.
# One of the words, elections-europeennes or ukraine, is not in the vocabulary.
# One of the words, elections-europeennes or président, is not in the vocabulary.
# One of the words, elections-europeennes or notte, is not in the vocabulary.
# similarité entre international et étudiant: -0.0241
# One of the words, international or poulter, is not in the vocabulary.
# similarité entre international et loi: -0.0599
# similarité entre international et match: -0.0095
# similarité entre international et conseiller: -0.0140
# similarité entre international et administratif: 0.0383
# similarité entre international et nom: -0.0326
# similarité entre international et université: 0.2222
# similarité entre international et burkinabé: 0.1191
# similarité entre international et ligne: 0.0202
# similarité entre international et université: 0.2222
# similarité entre international et celui: -0.0130
# similarité entre international et mine: -0.0369
# similarité entre international et neuf: -0.0306
# similarité entre international et américain: 0.2705
# similarité entre international et liste: -0.0982
# similarité entre international et cour: 0.1264
# One of the words, international or bardella, is not in the vocabulary.
# similarité entre international et proportionnelle: -0.0762
# similarité entre international et vote: -0.0734
# similarité entre international et vote: -0.0734
# similarité entre international et ukraine: 0.1872
# similarité entre international et président: 0.0592
# similarité entre international et notte: 0.0129
# similarité entre international et étudiant: -0.0241
# One of the words, international or poulter, is not in the vocabulary.
# similarité entre international et loi: -0.0599
# similarité entre international et match: -0.0095
# similarité entre international et conseiller: -0.0140
# similarité entre international et administratif: 0.0383
# similarité entre international et nom: -0.0326
# similarité entre international et université: 0.2222
# similarité entre international et burkinabé: 0.1191
# similarité entre international et ligne: 0.0202
# similarité entre international et université: 0.2222
# similarité entre international et celui: -0.0130
# similarité entre international et mine: -0.0369
# similarité entre international et neuf: -0.0306
# similarité entre international et américain: 0.2705
# similarité entre international et liste: -0.0982
# similarité entre international et cour: 0.1264
# One of the words, international or bardella, is not in the vocabulary.
# similarité entre international et proportionnelle: -0.0762
# similarité entre international et vote: -0.0734
# similarité entre international et vote: -0.0734
# similarité entre international et ukraine: 0.1872
# similarité entre international et président: 0.0592
# similarité entre international et notte: 0.0129
# similarité entre société et étudiant: -0.0833
# One of the words, société or poulter, is not in the vocabulary.
# similarité entre société et loi: 0.1048
# similarité entre société et match: -0.1153
# similarité entre société et conseiller: -0.0243
# similarité entre société et administratif: -0.0082
# similarité entre société et nom: 0.0742
# similarité entre société et université: -0.0292
# similarité entre société et burkinabé: -0.0446
# similarité entre société et ligne: 0.0513
# similarité entre société et université: -0.0292
# similarité entre société et celui: 0.0148
# similarité entre société et mine: 0.0440
# similarité entre société et neuf: 0.0143
# similarité entre société et américain: 0.0651
# similarité entre société et liste: -0.0598
# similarité entre société et cour: 0.0581
# One of the words, société or bardella, is not in the vocabulary.
# similarité entre société et proportionnelle: -0.0631
# similarité entre société et vote: 0.0386
# similarité entre société et vote: 0.0386
# similarité entre société et ukraine: -0.0491
# similarité entre société et président: 0.0573
# similarité entre société et notte: -0.0732

# %%
pearson_corr, pearson_pvalue = pearsonr(title_length, content_length)
